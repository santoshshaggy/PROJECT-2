# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("dataset1.csv")

# %%
df1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# 4    0.24
# ..    ...
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20
#
# [610 rows x 10 columns]

# %%
df1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
df1.describe().T
# Out:
#             count        mean         std   min     25%    50%      75%  \
# instant     610.0  305.500000  176.236111  1.00  153.25  305.5  457.750
# season      610.0    1.000000    0.000000  1.00    1.00    1.0    1.000
# yr          610.0    0.000000    0.000000  0.00    0.00    0.0    0.000
# mnth        610.0    1.000000    0.000000  1.00    1.00    1.0    1.000
# hr          610.0   11.795082    6.852107  0.00    6.00   12.0   18.000
# weekday     610.0    2.977049    2.054943  0.00    1.00    3.0    5.000
# weathersit  610.0    1.477049    0.643496  1.00    1.00    1.0    2.000
# temp        610.0    0.196885    0.081304  0.02    0.16    0.2    0.235
#
#                max
# instant     610.00
# season        1.00
# yr            0.00
# mnth          1.00
# hr           23.00
# weekday       6.00
# weathersit    4.00
# temp          0.46

# %%
df1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
df1['dteday'] = pd.to_datetime(df1['dteday'], format='%d-%m-%Y')
df1['yr']=df1['dteday'].dt.year
df1['mnth']=df1['dteday'].dt.month
df1['dteday']=df1['dteday'].dt.day

# %%
df1
# Out:
#      instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1       1       1  2011     1   0    False        6           1
# 1          2       1       1  2011     1   1    False        6           1
# 2          3       1       1  2011     1   2    False        6           1
# 3          4       1       1  2011     1   3    False        6           1
# 4          5       1       1  2011     1   4    False        6           1
# ..       ...     ...     ...   ...   ...  ..      ...      ...         ...
# 605      606      28       1  2011     1  11    False        5           3
# 606      607      28       1  2011     1  12    False        5           3
# 607      608      28       1  2011     1  13    False        5           3
# 608      609      28       1  2011     1  14    False        5           3
# 609      610      28       1  2011     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# 4    0.24
# ..    ...
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20
#
# [610 rows x 10 columns]

# %%
df2=pd.read_csv("dataset2.csv")

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
df2.describe().T
# Out:
#             count        mean         std   min       25%      50%       75%  \
# Unnamed: 0  610.0  304.500000  176.236111  0.00  152.2500  304.500  456.7500
# instant     610.0  305.500000  176.236111  1.00  153.2500  305.500  457.7500
# atemp       599.0    0.199935    0.078836  0.00    0.1515    0.197    0.2424
# hum         610.0    0.562475    0.175440  0.21    0.4325    0.520    0.6900
# windspeed   610.0    0.204851    0.121806  0.00    0.1045    0.194    0.2836
# casual      610.0    4.501639    6.319945  0.00    0.0000    2.000    6.0000
# registered  610.0   51.068852   47.021204  0.00   14.0000   43.000   70.0000
# cnt         610.0   55.570492   49.316802  1.00   16.0000   47.000   79.7500
#
#                  max
# Unnamed: 0  609.0000
# instant     610.0000
# atemp         0.4545
# hum           1.0000
# windspeed     0.5821
# casual       47.0000
# registered  247.0000
# cnt         249.0000

# %%
df2.drop("Unnamed: 0",axis=1, inplace=True)

# %%
df2.head()
# Out:
#    instant   atemp   hum  windspeed  casual  registered  cnt
# 0        1  0.2879  0.81        0.0       3          13   16
# 1        2  0.2727  0.80        0.0       8          32   40
# 2        3  0.2727  0.80        0.0       5          27   32
# 3        4  0.2879  0.75        0.0       3          10   13
# 4        5  0.2879  0.75        0.0       0           1    1

# %%
df2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df2["atemp"]=df2["atemp"].fillna(df2["atemp"].mean())

# %%
df2.isnull().sum()
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df2.count()
# Out:
# instant       610
# atemp         610
# hum           610
# windspeed     610
# casual        610
# registered    610
# cnt           610
# dtype: int64

# %%
df_merge=pd.merge(df1,df2,on='instant')

# %%
df_merge
# Out:
#      instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1       1       1  2011     1   0    False        6           1
# 1          2       1       1  2011     1   1    False        6           1
# 2          3       1       1  2011     1   2    False        6           1
# 3          4       1       1  2011     1   3    False        6           1
# 4          5       1       1  2011     1   4    False        6           1
# ..       ...     ...     ...   ...   ...  ..      ...      ...         ...
# 605      606      28       1  2011     1  11    False        5           3
# 606      607      28       1  2011     1  12    False        5           3
# 607      608      28       1  2011     1  13    False        5           3
# 608      609      28       1  2011     1  14    False        5           3
# 609      610      28       1  2011     1  15    False        5           2
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 0    0.24  0.2879  0.81     0.0000       3          13   16
# 1    0.22  0.2727  0.80     0.0000       8          32   40
# 2    0.22  0.2727  0.80     0.0000       5          27   32
# 3    0.24  0.2879  0.75     0.0000       3          10   13
# 4    0.24  0.2879  0.75     0.0000       0           1    1
# ..    ...     ...   ...        ...     ...         ...  ...
# 605  0.18  0.2121  0.93     0.1045       0          30   30
# 606  0.18  0.2121  0.93     0.1045       1          28   29
# 607  0.18  0.2121  0.93     0.1045       0          31   31
# 608  0.22  0.2727  0.80     0.0000       2          36   38
# 609  0.20  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 16 columns]

# %%
df_merge.head()
# Out:
#    instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1       1       1  2011     1   0    False        6           1
# 1        2       1       1  2011     1   1    False        6           1
# 2        3       1       1  2011     1   2    False        6           1
# 3        4       1       1  2011     1   3    False        6           1
# 4        5       1       1  2011     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    int32
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int32
#  4   mnth        610 non-null    int32
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  atemp       610 non-null    float64
#  11  hum         610 non-null    float64
#  12  windspeed   610 non-null    float64
#  13  casual      610 non-null    int64
#  14  registered  610 non-null    int64
#  15  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int32(3), int64(8)
# memory usage: 65.1 KB

# %%
df_merge.describe().T
# Out:
#             count         mean         std      min        25%       50%  \
# instant     610.0   305.500000  176.236111     1.00   153.2500   305.500
# dteday      610.0    13.824590    7.803859     1.00     7.0000    14.000
# season      610.0     1.000000    0.000000     1.00     1.0000     1.000
# yr          610.0  2011.000000    0.000000  2011.00  2011.0000  2011.000
# mnth        610.0     1.000000    0.000000     1.00     1.0000     1.000
# hr          610.0    11.795082    6.852107     0.00     6.0000    12.000
# weekday     610.0     2.977049    2.054943     0.00     1.0000     3.000
# weathersit  610.0     1.477049    0.643496     1.00     1.0000     1.000
# temp        610.0     0.196885    0.081304     0.02     0.1600     0.200
# atemp       610.0     0.199935    0.078120     0.00     0.1515     0.197
# hum         610.0     0.562475    0.175440     0.21     0.4325     0.520
# windspeed   610.0     0.204851    0.121806     0.00     0.1045     0.194
# casual      610.0     4.501639    6.319945     0.00     0.0000     2.000
# registered  610.0    51.068852   47.021204     0.00    14.0000    43.000
# cnt         610.0    55.570492   49.316802     1.00    16.0000    47.000
#
#                   75%        max
# instant      457.7500   610.0000
# dteday        21.0000    28.0000
# season         1.0000     1.0000
# yr          2011.0000  2011.0000
# mnth           1.0000     1.0000
# hr            18.0000    23.0000
# weekday        5.0000     6.0000
# weathersit     2.0000     4.0000
# temp           0.2350     0.4600
# atemp          0.2273     0.4545
# hum            0.6900     1.0000
# windspeed      0.2836     0.5821
# casual         6.0000    47.0000
# registered    70.0000   247.0000
# cnt           79.7500   249.0000

# %%
df3=pd.read_csv("dataset3.csv")

# %%
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 0    0.22  0.2273  0.64     0.1940       0          20   20
# 1    0.22  0.2273  0.64     0.1642       0          15   15
# 2    0.20  0.2121  0.64     0.1343       3           5    8
# 3    0.16  0.1818  0.69     0.1045       1           2    3
# 4    0.16  0.1818  0.64     0.1343       0           2    2
# ..    ...     ...   ...        ...     ...         ...  ...
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28
#
# [390 rows x 16 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
df3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3.describe().T
# Out:
#             count        mean         std       min       25%       50%  \
# instant     390.0  805.500000  112.727548  611.0000  708.2500  805.5000
# season      390.0    1.000000    0.000000    1.0000    1.0000    1.0000
# yr          390.0    0.000000    0.000000    0.0000    0.0000    0.0000
# mnth        390.0    1.800000    0.400514    1.0000    2.0000    2.0000
# hr          390.0   11.687179    6.980295    0.0000    6.0000   12.0000
# weekday     390.0    2.989744    2.149884    0.0000    1.0000    3.0000
# weathersit  390.0    1.484615    0.663805    1.0000    1.0000    1.0000
# temp        390.0    0.220000    0.073095    0.0600    0.1600    0.2200
# atemp       390.0    0.230424    0.069455    0.0758    0.1818    0.2273
# hum         390.0    0.613769    0.202361    0.2100    0.4500    0.6000
# windspeed   390.0    0.179416    0.138551    0.0000    0.0896    0.1642
# casual      390.0    5.576923    9.317478    0.0000    1.0000    3.0000
# registered  390.0   57.002564   49.070198    0.0000   17.0000   48.0000
# cnt         390.0   62.579487   53.274838    1.0000   18.5000   52.0000
#
#                  75%        max
# instant     902.7500  1000.0000
# season        1.0000     1.0000
# yr            0.0000     0.0000
# mnth          2.0000     2.0000
# hr           18.0000    23.0000
# weekday       5.0000     6.0000
# weathersit    2.0000     3.0000
# temp          0.2600     0.4200
# atemp         0.2727     0.4242
# hum           0.7500     1.0000
# windspeed     0.2836     0.5821
# casual        6.0000    62.0000
# registered   83.7500   236.0000
# cnt          88.7500   243.0000

# %%
df3['dteday']=pd.to_datetime(df3['dteday'])
df3['yr']=df3['dteday'].dt.year
df3['mnth']=df3['dteday'].dt.month
df3['dteday']=df3['dteday'].dt.day

# %%
df3
# Out:
#      instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620      29       1  2011     1   1    False        6           1
# 1        621      29       1  2011     1   2    False        6           1
# 2        622      29       1  2011     1   3    False        6           1
# 3        623      29       1  2011     1   4    False        6           1
# 4        624      29       1  2011     1   6    False        6           1
# ..       ...     ...     ...   ...   ...  ..      ...      ...         ...
# 385      615      28       1  2011     1  20    False        5           2
# 386      616      28       1  2011     1  21    False        5           2
# 387      617      28       1  2011     1  22    False        5           1
# 388      618      28       1  2011     1  23    False        5           1
# 389      619      29       1  2011     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 0    0.22  0.2273  0.64     0.1940       0          20   20
# 1    0.22  0.2273  0.64     0.1642       0          15   15
# 2    0.20  0.2121  0.64     0.1343       3           5    8
# 3    0.16  0.1818  0.69     0.1045       1           2    3
# 4    0.16  0.1818  0.64     0.1343       0           2    2
# ..    ...     ...   ...        ...     ...         ...  ...
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28
#
# [390 rows x 16 columns]

# %%
df=pd.concat([df_merge, df3], axis=0, ignore_index=True)

# %%
df
# Out:
#      instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1       1       1  2011     1   0    False        6           1
# 1          2       1       1  2011     1   1    False        6           1
# 2          3       1       1  2011     1   2    False        6           1
# 3          4       1       1  2011     1   3    False        6           1
# 4          5       1       1  2011     1   4    False        6           1
# ..       ...     ...     ...   ...   ...  ..      ...      ...         ...
# 995      615      28       1  2011     1  20    False        5           2
# 996      616      28       1  2011     1  21    False        5           2
# 997      617      28       1  2011     1  22    False        5           1
# 998      618      28       1  2011     1  23    False        5           1
# 999      619      29       1  2011     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 0    0.24  0.2879  0.81     0.0000       3          13   16
# 1    0.22  0.2727  0.80     0.0000       8          32   40
# 2    0.22  0.2727  0.80     0.0000       5          27   32
# 3    0.24  0.2879  0.75     0.0000       3          10   13
# 4    0.24  0.2879  0.75     0.0000       0           1    1
# ..    ...     ...   ...        ...     ...         ...  ...
# 995  0.24  0.2273  0.70     0.1940       1          61   62
# 996  0.22  0.2273  0.75     0.1343       1          57   58
# 997  0.24  0.2121  0.65     0.3582       0          26   26
# 998  0.24  0.2273  0.60     0.2239       1          22   23
# 999  0.22  0.1970  0.64     0.3582       2          26   28
#
# [1000 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df["holiday_code"]=lb.fit_transform(df["holiday"])

# %%
df
# Out:
#      instant  dteday  season    yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1       1       1  2011     1   0    False        6           1
# 1          2       1       1  2011     1   1    False        6           1
# 2          3       1       1  2011     1   2    False        6           1
# 3          4       1       1  2011     1   3    False        6           1
# 4          5       1       1  2011     1   4    False        6           1
# ..       ...     ...     ...   ...   ...  ..      ...      ...         ...
# 995      615      28       1  2011     1  20    False        5           2
# 996      616      28       1  2011     1  21    False        5           2
# 997      617      28       1  2011     1  22    False        5           1
# 998      618      28       1  2011     1  23    False        5           1
# 999      619      29       1  2011     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt  holiday_code
# 0    0.24  0.2879  0.81     0.0000       3          13   16             0
# 1    0.22  0.2727  0.80     0.0000       8          32   40             0
# 2    0.22  0.2727  0.80     0.0000       5          27   32             0
# 3    0.24  0.2879  0.75     0.0000       3          10   13             0
# 4    0.24  0.2879  0.75     0.0000       0           1    1             0
# ..    ...     ...   ...        ...     ...         ...  ...           ...
# 995  0.24  0.2273  0.70     0.1940       1          61   62             0
# 996  0.22  0.2273  0.75     0.1343       1          57   58             0
# 997  0.24  0.2121  0.65     0.3582       0          26   26             0
# 998  0.24  0.2273  0.60     0.2239       1          22   23             0
# 999  0.22  0.1970  0.64     0.3582       2          26   28             0
#
# [1000 rows x 17 columns]

# %%
df.drop("holiday",axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instant       1000 non-null   int64
#  1   dteday        1000 non-null   int32
#  2   season        1000 non-null   int64
#  3   yr            1000 non-null   int32
#  4   mnth          1000 non-null   int32
#  5   hr            1000 non-null   int64
#  6   weekday       1000 non-null   int64
#  7   weathersit    1000 non-null   int64
#  8   temp          1000 non-null   float64
#  9   atemp         1000 non-null   float64
#  10  hum           1000 non-null   float64
#  11  windspeed     1000 non-null   float64
#  12  casual        1000 non-null   int64
#  13  registered    1000 non-null   int64
#  14  cnt           1000 non-null   int64
#  15  holiday_code  1000 non-null   int64
# dtypes: float64(4), int32(3), int64(9)
# memory usage: 113.4 KB

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.count()
# Out:
# instant         1000
# dteday          1000
# season          1000
# yr              1000
# mnth            1000
# hr              1000
# weekday         1000
# weathersit      1000
# temp            1000
# atemp           1000
# hum             1000
# windspeed       1000
# casual          1000
# registered      1000
# cnt             1000
# holiday_code    1000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   instant       1000 non-null   int64
#  1   dteday        1000 non-null   int32
#  2   season        1000 non-null   int64
#  3   yr            1000 non-null   int32
#  4   mnth          1000 non-null   int32
#  5   hr            1000 non-null   int64
#  6   weekday       1000 non-null   int64
#  7   weathersit    1000 non-null   int64
#  8   temp          1000 non-null   float64
#  9   atemp         1000 non-null   float64
#  10  hum           1000 non-null   float64
#  11  windspeed     1000 non-null   float64
#  12  casual        1000 non-null   int64
#  13  registered    1000 non-null   int64
#  14  cnt           1000 non-null   int64
#  15  holiday_code  1000 non-null   int64
# dtypes: float64(4), int32(3), int64(9)
# memory usage: 113.4 KB

# %%
df.head()
# Out:
#    instant  dteday  season    yr  mnth  hr  weekday  weathersit  temp   atemp  \
# 0        1       1       1  2011     1   0        6           1  0.24  0.2879
# 1        2       1       1  2011     1   1        6           1  0.22  0.2727
# 2        3       1       1  2011     1   2        6           1  0.22  0.2727
# 3        4       1       1  2011     1   3        6           1  0.24  0.2879
# 4        5       1       1  2011     1   4        6           1  0.24  0.2879
#
#     hum  windspeed  casual  registered  cnt  holiday_code
# 0  0.81        0.0       3          13   16             0
# 1  0.80        0.0       8          32   40             0
# 2  0.80        0.0       5          27   32             0
# 3  0.75        0.0       3          10   13             0
# 4  0.75        0.0       0           1    1             0

# %%
df.describe().T
# Out:
#                count         mean         std      min        25%        50%  \
# instant       1000.0   500.500000  288.819436     1.00   250.7500   500.5000
# dteday        1000.0    12.992000    8.656724     1.00     6.0000    11.0000
# season        1000.0     1.000000    0.000000     1.00     1.0000     1.0000
# yr            1000.0  2011.000000    0.000000  2011.00  2011.0000  2011.0000
# mnth          1000.0     1.312000    0.463542     1.00     1.0000     1.0000
# hr            1000.0    11.753000    6.899101     0.00     6.0000    12.0000
# weekday       1000.0     2.982000    2.091423     0.00     1.0000     3.0000
# weathersit    1000.0     1.480000    0.651171     1.00     1.0000     1.0000
# temp          1000.0     0.205900    0.078977     0.02     0.1600     0.2000
# atemp         1000.0     0.211826    0.076290     0.00     0.1667     0.2121
# hum           1000.0     0.582480    0.187977     0.21     0.4400     0.5500
# windspeed     1000.0     0.194931    0.129126     0.00     0.1045     0.1642
# casual        1000.0     4.921000    7.643899     0.00     0.0000     3.0000
# registered    1000.0    53.383000   47.893968     0.00    15.0000    46.0000
# cnt           1000.0    58.304000   50.985558     1.00    16.0000    49.0000
# holiday_code  1000.0     0.024000    0.153126     0.00     0.0000     0.0000
#
#                     75%        max
# instant        750.2500  1000.0000
# dteday          20.0000    31.0000
# season           1.0000     1.0000
# yr            2011.0000  2011.0000
# mnth             2.0000     2.0000
# hr              18.0000    23.0000
# weekday          5.0000     6.0000
# weathersit       2.0000     4.0000
# temp             0.2400     0.4600
# atemp            0.2576     0.4545
# hum              0.7000     1.0000
# windspeed        0.2836     0.5821
# casual           6.0000    62.0000
# registered      74.0000   247.0000
# cnt             83.0000   249.0000
# holiday_code     0.0000     1.0000

# %%
df.isnull().sum()
# Out:
# instant         0
# dteday          0
# season          0
# yr              0
# mnth            0
# hr              0
# weekday         0
# weathersit      0
# temp            0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# holiday_code    0
# dtype: int64

# %%
median_values= df.median()
print("Median values for all numeric columns:")
print(median_values)
# Out:
# Median values for all numeric columns:
# instant          500.5000
# dteday            11.0000
# season             1.0000
# yr              2011.0000
# mnth               1.0000
# hr                12.0000
# weekday            3.0000
# weathersit         1.0000
# temp               0.2000
# atemp              0.2121
# hum                0.5500
# windspeed          0.1642
# casual             3.0000
# registered        46.0000
# cnt               49.0000
# holiday_code       0.0000
# dtype: float64

# %%
mean_values= df.mean()
print("Mean values for all numeric columns:")
print(mean_values)
# Out:
# Mean values for all numeric columns:
# instant          500.500000
# dteday            12.992000
# season             1.000000
# yr              2011.000000
# mnth               1.312000
# hr                11.753000
# weekday            2.982000
# weathersit         1.480000
# temp               0.205900
# atemp              0.211826
# hum                0.582480
# windspeed          0.194931
# casual             4.921000
# registered        53.383000
# cnt               58.304000
# holiday_code       0.024000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ####mentioning am or pm to check count of rentals taken in day and night

# %%
def am_or_pm(x): 
    if x > 11: 
        return 1
    else: 
        return 0
  

df['am_or_pm']=df['hr'].apply(am_or_pm)

# %%
df
# Out:
#      instant  dteday  season    yr  mnth  hr  weekday  weathersit  temp  \
# 0          1       1       1  2011     1   0        6           1  0.24
# 1          2       1       1  2011     1   1        6           1  0.22
# 2          3       1       1  2011     1   2        6           1  0.22
# 3          4       1       1  2011     1   3        6           1  0.24
# 4          5       1       1  2011     1   4        6           1  0.24
# ..       ...     ...     ...   ...   ...  ..      ...         ...   ...
# 995      615      28       1  2011     1  20        5           2  0.24
# 996      616      28       1  2011     1  21        5           2  0.22
# 997      617      28       1  2011     1  22        5           1  0.24
# 998      618      28       1  2011     1  23        5           1  0.24
# 999      619      29       1  2011     1   0        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt  holiday_code  am_or_pm
# 0    0.2879  0.81     0.0000       3          13   16             0         0
# 1    0.2727  0.80     0.0000       8          32   40             0         0
# 2    0.2727  0.80     0.0000       5          27   32             0         0
# 3    0.2879  0.75     0.0000       3          10   13             0         0
# 4    0.2879  0.75     0.0000       0           1    1             0         0
# ..      ...   ...        ...     ...         ...  ...           ...       ...
# 995  0.2273  0.70     0.1940       1          61   62             0         1
# 996  0.2273  0.75     0.1343       1          57   58             0         1
# 997  0.2121  0.65     0.3582       0          26   26             0         1
# 998  0.2273  0.60     0.2239       1          22   23             0         1
# 999  0.1970  0.64     0.3582       2          26   28             0         0
#
# [1000 rows x 17 columns]

# %%
features = ['season', 'weathersit','am_or_pm','holiday_code','yr', 'weekday'] 
  
plt.subplots(figsize=(20, 10)) 
for i, col in enumerate(features): 
    plt.subplot(2, 3, i + 1) 
    df.groupby(col).mean()['cnt'].plot.bar() 
plt.show()

# %%
features = ['temp', 'windspeed'] 
  
plt.subplots(figsize=(15, 5)) 
for i, col in enumerate(features): 
  plt.subplot(1, 2, i + 1) 
  sns.distplot(df[col]) 
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, x="windspeed",kde=True, color="blue", label="Windspeed")
sns.histplot(data=df, x="temp", kde=True,color="orange", label="Temperature")
plt.legend()
plt.title("Distribution of Windspeed and Temperature")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
features = ['temp', 'windspeed']

plt.subplots(figsize=(15, 5)) 
for i, col in enumerate(features):
    plt.subplot(1, 2, i + 1) 
    sns.boxplot(y=df[col]) 
    plt.title(f'Boxplot of {col}')  
plt.tight_layout() 
plt.show()

# %%
features = ['hum', 'casual', 'registered', 'cnt'] 
  
plt.subplots(figsize=(15, 10)) 
for i, col in enumerate(features): 
    plt.subplot(2, 2, i + 1) 
    sns.boxplot(df[col])
    plt.title(col)
plt.show()

# %%
sns.heatmap(df.corr() > 0.8,annot=True,cbar=False) 
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
num_column=df.select_dtypes(include=['float64','int64']).columns

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(num_column,1):
    plt.subplot(5, 5, i)
    sns.boxplot(y=df[col])
    plt.title(col)
    
plt.tight_layout()
plt.show()

# %%
#checking number of outliers for each numerical key feature using IQR method

# Initialize a dictionary to store the number of outliers for each feature
outliers_count = {}

# Calculate the number of outliers using the IQR method
for feature in num_column:
    if feature in df.columns:
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR
        outliers = df[(df[feature] < lower_limit) | (df[feature] > upper_limit)]
        outliers_count[feature] = len(outliers)
        
    else:
        print(f"Column '{feature}' not found in DataFrame")

# Display the number of outliers for each key feature
print("Number of outliers in each key feature:")
for feature, count in outliers_count.items():
    print(f"{feature}:{count}")
# Out:
# Number of outliers in each key feature:
# instant:0
# season:0
# hr:0
# weekday:0
# weathersit:1
# temp:66
# atemp:41
# hum:0
# windspeed:4
# casual:66
# registered:45
# cnt:30
# holiday_code:24
# am_or_pm:0

# %% [markdown]
# Handling Outliers

# %%
#FOR WEATHERSIT FEATURE-

q1=df["weathersit"].quantile(0.25)
q2=df["weathersit"].quantile(0.50)
q3=df["weathersit"].quantile(0.75)
print("The first quantile is",q1)
print("The second quantile is",q2)
print("The third quantile is",q3)

IQR=q3-q1
print("The inner quantile is",IQR)

lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("The lower_limit is",lower_limit)
print("The upper limit is",upper_limit)

df["weathersit"] = np.where(df["weathersit"] < 3.5, df["weathersit"], 3.5)
# Out:
# The first quantile is 1.0
# The second quantile is 1.0
# The third quantile is 2.0
# The inner quantile is 1.0
# The lower_limit is -0.5
# The upper limit is 3.5

# %%
q1=df["casual"].quantile(0.25)
q2=df["casual"].quantile(0.50)
q3=df["casual"].quantile(0.75)
print("The first quantile is",q1)
print("The second quantile is",q2)
print("The third quantile is",q3)

IQR=q3-q1
print("The inner quantile is",IQR)

lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("The lower_limit is",lower_limit)
print("The upper limit is",upper_limit)

#Handling Outlier imputing the values of casual column which are more than 15 using np.where clause

df["casual"] = np.where(df["casual"] < 16, df["casual"], 15)
# Out:
# The first quantile is 0.0
# The second quantile is 3.0
# The third quantile is 6.0
# The inner quantile is 6.0
# The lower_limit is -9.0
# The upper limit is 15.0

# %%
df["temp"].mean()
# Out:
# 0.20590000000000003

# %%
q1=df["temp"].quantile(0.25)
q2=df["temp"].quantile(0.50)
q3=df["temp"].quantile(0.75)
print("The first quantile is",q1)
print("The second quantile is",q2)
print("The third quantile is",q3)

IQR=q3-q1
print("The inner quantile is",IQR)

lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("The lower_limit is",lower_limit)
print("The upper limit is",upper_limit)

df["temp"].mean()
print("the mean is",df["temp"].mean())

df["temp"] = np.where(df["temp"] >0.36, df["temp"].mean(), df["temp"])
df["temp"] = np.where(df["temp"] < 0.04000000000000002, df["temp"].mean(), df["temp"])
# Out:
# The first quantile is 0.16
# The second quantile is 0.2
# The third quantile is 0.24
# The inner quantile is 0.07999999999999999
# The lower_limit is 0.04000000000000002
# The upper limit is 0.36
# the mean is 0.20590000000000003

# %%
df["atemp"].mean()
# Out:
# 0.2118255838063439

# %%
q1=df["atemp"].quantile(0.25)
q2=df["atemp"].quantile(0.50)
q3=df["atemp"].quantile(0.75)
print("The first quantile is",q1)
print("The second quantile is",q2)
print("The third quantile is",q3)

IQR=q3-q1
print("The inner quantile is",IQR)

lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("The lower_limit is",lower_limit)
print("The upper limit is",upper_limit)

df["atemp"].mean()
print("the mean is",df["atemp"].mean())


df["atemp"] = np.where(df["atemp"] > 0.35595000000000004, df["atemp"].mean(), df["atemp"])
df["atemp"] = np.where(df["atemp"] < 0.05314999999999996, df["atemp"].mean(), df["atemp"])
# Out:
# The first quantile is 0.1667
# The second quantile is 0.2121
# The third quantile is 0.2576
# The inner quantile is 0.09090000000000001
# The lower_limit is 0.03034999999999996
# The upper limit is 0.39395
# the mean is 0.2118255838063439

# %%
sns.boxplot(df["atemp"])
# Out:
# <Axes: ylabel='atemp'>

# %%
q1=df["windspeed"].quantile(0.25)
q2=df["windspeed"].quantile(0.50)
q3=df["windspeed"].quantile(0.75)
print("The first quantile is",q1)
print("The second quantile is",q2)
print("The third quantile is",q3)

IQR=q3-q1
print("The inner quantile is",IQR)

lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("The lower_limit is",lower_limit)
print("The upper limit is",upper_limit)

df["windspeed"] = np.where(df["windspeed"] < 0.5522500000000001, df["windspeed"], 0.55)
# Out:
# The first quantile is 0.1045
# The second quantile is 0.1642
# The third quantile is 0.2836
# The inner quantile is 0.17910000000000004
# The lower_limit is -0.16415000000000007
# The upper limit is 0.5522500000000001

# %%
q1=df["registered"].quantile(0.25)
q2=df["registered"].quantile(0.50)
q3=df["registered"].quantile(0.75)
print("The first quantile is",q1)
print("The second quantile is",q2)
print("The third quantile is",q3)

IQR=q3-q1
print("The inner quantile is",IQR)

lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("The lower_limit is",lower_limit)
print("The upper limit is",upper_limit)

df["registered"] = np.where(df["registered"] < 162.5, df["registered"], 162.5)
# Out:
# The first quantile is 15.0
# The second quantile is 46.0
# The third quantile is 74.0
# The inner quantile is 59.0
# The lower_limit is -73.5
# The upper limit is 162.5

# %%
q1=df["cnt"].quantile(0.25)
q2=df["cnt"].quantile(0.50)
q3=df["cnt"].quantile(0.75)
print("The first quantile is",q1)
print("The second quantile is",q2)
print("The third quantile is",q3)

IQR=q3-q1
print("The inner quantile is",IQR)

lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
print("The lower_limit is",lower_limit)
print("The upper limit is",upper_limit)

df["cnt"] = np.where(df["cnt"] < 183.5, df["cnt"], 183.5)
# Out:
# The first quantile is 16.0
# The second quantile is 49.0
# The third quantile is 83.0
# The inner quantile is 67.0
# The lower_limit is -84.5
# The upper limit is 183.5

# %%
outliers_count = {}

# Calculate the number of outliers using the IQR method
for feature in num_column:
    if feature in df.columns:
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR
        outliers = df[(df[feature] < lower_limit) | (df[feature] > upper_limit)]
        outliers_count[feature] = len(outliers)
        
    else:
        print(f"Column '{feature}' not found in DataFrame")

# Display the number of outliers for each key feature
print("Number of outliers in each key feature:")
for feature, count in outliers_count.items():
    print(f"{feature}:{count}")
# Out:
# Number of outliers in each key feature:
# instant:0
# season:0
# hr:0
# weekday:0
# weathersit:0
# temp:0
# atemp:0
# hum:0
# windspeed:0
# casual:0
# registered:0
# cnt:0
# holiday_code:24
# am_or_pm:0

# %%
# after handling outliers
plt.figure(figsize=(15,10))
for i,col in enumerate(num_column,1):
    plt.subplot(5, 5, i)
    sns.boxplot(y=df[col])
    plt.title(col)
    
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 10)) 
sns.lineplot(df,ax=axes[0, 1])  # First row, second column
axes[0, 1].set_title('Line Plot')
plt.tight_layout()
plt.show()

# %%
df.describe().T
# Out:
#                count         mean         std        min        25%  \
# instant       1000.0   500.500000  288.819436     1.0000   250.7500
# dteday        1000.0    12.992000    8.656724     1.0000     6.0000
# season        1000.0     1.000000    0.000000     1.0000     1.0000
# yr            1000.0  2011.000000    0.000000  2011.0000  2011.0000
# mnth          1000.0     1.312000    0.463542     1.0000     1.0000
# hr            1000.0    11.753000    6.899101     0.0000     6.0000
# weekday       1000.0     2.982000    2.091423     0.0000     1.0000
# weathersit    1000.0     1.479500    0.649424     1.0000     1.0000
# temp          1000.0     0.201263    0.060746     0.0600     0.1600
# atemp         1000.0     0.205792    0.060410     0.0606     0.1667
# hum           1000.0     0.582480    0.187977     0.2100     0.4400
# windspeed     1000.0     0.194803    0.128756     0.0000     0.1045
# casual        1000.0     4.059000    4.515519     0.0000     0.0000
# registered    1000.0    52.075500   44.146772     0.0000    15.0000
# cnt           1000.0    57.557000   48.822606     1.0000    16.0000
# holiday_code  1000.0     0.024000    0.153126     0.0000     0.0000
# am_or_pm      1000.0     0.518000    0.499926     0.0000     0.0000
#
#                       50%        75%        max
# instant        500.500000   750.2500  1000.0000
# dteday          11.000000    20.0000    31.0000
# season           1.000000     1.0000     1.0000
# yr            2011.000000  2011.0000  2011.0000
# mnth             1.000000     2.0000     2.0000
# hr              12.000000    18.0000    23.0000
# weekday          3.000000     5.0000     6.0000
# weathersit       1.000000     2.0000     3.5000
# temp             0.200000     0.2400     0.3600
# atemp            0.211826     0.2424     0.3485
# hum              0.550000     0.7000     1.0000
# windspeed        0.164200     0.2836     0.5522
# casual           3.000000     6.0000    15.0000
# registered      46.000000    74.0000   162.5000
# cnt             49.000000    83.0000   183.5000
# holiday_code     0.000000     0.0000     1.0000
# am_or_pm         1.000000     1.0000     1.0000

# %% [markdown]
# #### Plotting histogram for numerical features to check skewness

# %%
# Histograms
df[num_column].hist(bins=10, figsize=(15, 10))
plt.suptitle('Histograms of numerical features')
  
plt.tight_layout()
plt.show()

# %%
df['cnt'].hist(bins=30)

plt.title('')
plt.xlabel('rental counts')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# # Bar charts
# #cat_columns=df.select_dtypes(exclude=['float64','int64']).columns
# #plt.figure(figsize=(10, 10))
# #plt.scatter(df[''],df['cnt'])
# #plt.title('')
# #plt.xlabel('windspeed')
# #plt.ylabel('cnt')
# #plt.show()
#
# plt.figure(figsize=(8, 6))
# plt.plot(df['holiday_code'], df['cnt'], marker='o', color='green', linewidth=2, label='holiday_code vs total rentals')
# plt.title("Effect of holiday_code on total rentals")
# plt.xlabel("holiday_code")
# plt.ylabel("cnt")
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# ####

# %%
# Calculate the correlation matrix
correlation_matrix = df[num_column].corr()

# %%
sns.pairplot
# Out:
# <function seaborn.axisgrid.pairplot(data, *, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)>

# %%
correlation_matrix
# Out:
#                instant  season        hr   weekday  weathersit      temp  \
# instant       1.000000     NaN  0.000060  0.008157    0.030293  0.088818
# season             NaN     NaN       NaN       NaN         NaN       NaN
# hr            0.000060     NaN  1.000000  0.007531   -0.056427  0.171810
# weekday       0.008157     NaN  0.007531  1.000000    0.060162 -0.067124
# weathersit    0.030293     NaN -0.056427  0.060162    1.000000  0.073788
# temp          0.088818     NaN  0.171810 -0.067124    0.073788  1.000000
# atemp         0.115049     NaN  0.128380  0.026625    0.132875  0.843461
# hum           0.062116     NaN -0.194853  0.062469    0.539428  0.014294
# windspeed    -0.058066     NaN  0.116723 -0.057283   -0.178706  0.052990
# casual        0.022284     NaN  0.286666 -0.030732   -0.109843  0.432130
# registered    0.077648     NaN  0.388103  0.021644   -0.124809  0.214563
# cnt           0.081803     NaN  0.383688  0.011656   -0.129774  0.257987
# holiday_code -0.063013     NaN -0.005753 -0.148682    0.166009 -0.065677
# am_or_pm      0.000388     NaN  0.863407  0.005097   -0.048964  0.267655
#
#                  atemp       hum  windspeed    casual  registered       cnt  \
# instant       0.115049  0.062116  -0.058066  0.022284    0.077648  0.081803
# season             NaN       NaN        NaN       NaN         NaN       NaN
# hr            0.128380 -0.194853   0.116723  0.286666    0.388103  0.383688
# weekday       0.026625  0.062469  -0.057283 -0.030732    0.021644  0.011656
# weathersit    0.132875  0.539428  -0.178706 -0.109843   -0.124809 -0.129774
# temp          0.843461  0.014294   0.052990  0.432130    0.214563  0.257987
# atemp         1.000000  0.181513  -0.322131  0.350432    0.159228  0.194881
# hum           0.181513  1.000000  -0.385251 -0.297555   -0.247171 -0.265826
# windspeed    -0.322131 -0.385251   1.000000  0.114481    0.099695  0.110781
# casual        0.350432 -0.297555   0.114481  1.000000    0.431884  0.527755
# registered    0.159228 -0.247171   0.099695  0.431884    1.000000  0.989682
# cnt           0.194881 -0.265826   0.110781  0.527755    0.989682  1.000000
# holiday_code -0.075372 -0.037542  -0.000958  0.019666   -0.054316 -0.051063
# am_or_pm      0.203875 -0.263682   0.139907  0.387305    0.374609  0.386616
#
#               holiday_code  am_or_pm
# instant          -0.063013  0.000388
# season                 NaN       NaN
# hr               -0.005753  0.863407
# weekday          -0.148682  0.005097
# weathersit        0.166009 -0.048964
# temp             -0.065677  0.267655
# atemp            -0.075372  0.203875
# hum              -0.037542 -0.263682
# windspeed        -0.000958  0.139907
# casual            0.019666  0.387305
# registered       -0.054316  0.374609
# cnt              -0.051063  0.386616
# holiday_code      1.000000 -0.005649
# am_or_pm         -0.005649  1.000000

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
for feature in num_column:
     if feature!=['season','weekday','hr','mnth','temp','atemp','dteday','holiday_code']:
        plt.figure(figsize=(5, 4))
        scatter = plt.scatter(df[feature], df['cnt'], alpha=0.5, c=df[feature], cmap='viridis')  
        plt.title(f'Scatter plot of {feature} vs cnt')
        plt.xlabel(feature)
        plt.ylabel('cnt')
        plt.colorbar(scatter, label=f'{feature} Value')  
        plt.grid(True)
        plt.show()
